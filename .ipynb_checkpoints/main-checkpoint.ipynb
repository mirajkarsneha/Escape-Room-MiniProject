# %%
# define rooms and items
from functions import linebreak, start_game, play_room, explore_room, get_next_room_of_door, examine_item
couch = {
    "name": "couch",
    "type": "furniture",
}
piano = {
    "name": "piano",
    "type": "furniture",
}
queen_bed = {
    "name": "queen bed",
    "type": "furniture",
}
double_bed = {
    "name": "double bed",
    "type": "furniture",
}
dresser = {
    "name": "dresser",
    "type": "furniture",
}
diningtable = {
    "name": "diningtable",
    "type": "furniture",
}
door_a = {
    "name": "door a",
    "type": "door",
}
door_b = {
    "name": "door b",
    "type": "door",
}
door_c = {
    "name": "door c",
    "type": "door",
}
door_d = {
    "name": "door d",
    "type": "door",
}
key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}
key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}
key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}
key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}
game_room = {
    "name": "game room",
    "type": "room",
}
bed_room1 = {
    "name": "bed room1",
    "type": "room",
}
bed_room2 = {
    "name": "bed room2",
    "type": "room",
}
living_room = {
    "name": "living room",
    "type": "room",
}
outside = {
  "name": "outside"
}

all_rooms = [game_room, bed_room1, bed_room2, living_room, outside]

all_doors = [door_a, door_b, door_c, door_d]

# define which items/rooms are related

object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "door a": [game_room, bed_room1],
    "bed room1": [queen_bed, door_a, door_b, door_c],
    "queen bed": [key_b],
    "door b": [bed_room1, bed_room2],
    "bed room2": [dresser, double_bed, door_b],
    "double bed":[key_c],
    "dresser": [key_d],
    "door c": [bed_room1, living_room],
    "living room": [diningtable, door_c, door_d],
    "door d": [living_room, outside],
    "outside": [door_d]
}
# define game state. Do not directly change this dict.
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}
    
game_state = INIT_GAME_STATE.copy()

start_game()
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 117
#     109 INIT_GAME_STATE = {
#     110     "current_room": game_room,
#     111     "keys_collected": [],
#     112     "target_room": outside
#     113 }
#     115 game_state = INIT_GAME_STATE.copy()
# --> 117 start_game(game_state)
#
# File ~/Documents/Ironhack/MiniProject/Escape-Room-MiniProject/functions.py:19, in start_game(game_state)
#      15 """
#      16 Start the game
#      17 """
#      18 print("You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!")
# ---> 19 play_room(game_state["current_room"])
#
# File ~/Documents/Ironhack/MiniProject/Escape-Room-MiniProject/functions.py:27, in play_room(room)
#      21 def play_room(room):
#      22     """
#      23     Play a room. First check if the room being played is the target room.
#      24     If it is, the game will end with success. Otherwise, let player either
#      25     explore (list all items in this room) or examine an item found here.
#      26     """
# ---> 27     game_state["current_room"] = room
#      28     if(game_state["current_room"] == game_state["target_room"]):
#      29         print("Congrats! You escaped the room!")
#
# NameError: name 'game_state' is not defined
